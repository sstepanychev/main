# %% [markdown]
# <a href="https://colab.research.google.com/github/sstepanychev/main/blob/master/%D0%98%D0%BD%D1%82%D0%B5%D0%BD%D1%81%D0%B8%D0%B2_%D0%A3%D0%98%D0%98_%D0%94%D0%B5%D0%BD%D1%8C_2_%D0%9E%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0_%D1%82%D0%B5%D0%BA%D1%81%D1%82%D0%BE%D0%B2_%7C_%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2><b>Порядок сдачи домашнего задания</b></h2>
#
# 1. Сохранить копию ноутбука на свой гугл диск (File/Save a copy in drive)
# 2. Выполнить все задания ноутбука
# 3. Заполнить [форму сдачи ДЗ](https://forms.gle/rwidNarnDgHGPPmL9)
# 4. Открыть доступ к ноутбуку и прикрепить ссылку в форму сдачи ДЗ
#
# Демонстрационный ролик:

# %% [markdown]
# ![hommework.gif](data:image/gif;base64,...)

# %% [markdown]
# Ссылка на [ноутбук занятия](https://colab.research.google.com/drive/1S-qJ2OnFRDpu04VCGl05JXEMc3NOeuf1?usp=sharing)

# %% [markdown]
# <h1> <b> Задача №1 </b> </h1>
#
# <i>Разминочное</i>

# %% [markdown]
# **Описание задачи**
#
# Используя ноутбук занятия, попробуйте восстановить ход решения задачи: «Подбор кандидата на должность менеджера по продажам»
#
# Ниже будут даны подсказки для выполнения задания.
#
# *Рекомендация: полностью весь код набирайте руками, не копируя текст из ноутбука*

# %% [markdown]
# **1. Запустите ячейку ниже для установки модуля УИИ**

# %%
#@title Установка модуля УИИ
# !rm -rf sample_data

import seaborn as sns
import random
import os
import numpy as np
import tensorflow as tf
import gdown
from IPython.display import clear_output

# !pip -q install pymorphy2
# !pip -q install python-Levenshtein

# Установочные параметры
sns.set(style='darkgrid')
seed_value = 12
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
if not os.path.exists('/content/IntensiveTerra'):
  os.mkdir('/content/IntensiveTerra')
os.chdir('/content/IntensiveTerra')

# Загрузка модуля
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/intensivedaytwo.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/check_for_errors.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/dataset.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/text_process.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/квартиры.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/модель.py', None, quiet=True)

import intensivedaytwo

demo_ai = intensivedaytwo.TerraIntensive()
clear_output(wait=True)
# Out:
#      |████████████████████████████████| 55 kB 3.9 MB/s
#      |████████████████████████████████| 8.2 MB 61.8 MB/s
#      |████████████████████████████████| 50 kB 5.6 MB/s
# ...

# %% [markdown]
# **2. Загрузите датасет с информацией**:

# %%
# Ваше решение

# %% [markdown]
# **3. Выведите примеры резюме:**

# %%
# Ваше решение

# %% [markdown]
# **4. Сформируйте обучающую и проверочную выборки**:

# %%
# Ваше решение

# %% [markdown]
# **5. Укажите слои создаваемой нейронной сети:**

# %%
# Задание слоев нейронной сети
layers = ''

# Создание нейронной сети
demo_ai.create_model(layers)

# %% [markdown]
# **6. Обучите созданную модель:**
#
# *Можете указать произвольное количество эпох*

# %%
# Ваше решение

# %% [markdown]
# **7. Протестируйте Вашу модель**:

# %%
# Ваше решение

# %% [markdown]
# <h1> <b> Задача №2 </b> </h1>
#
# <i>Закрепляющая</i>

# %% [markdown]
# **Описание задачи**
#
# Воспроизведите работу по созданию модели для распознавания отзывов на автомобиль тесла.
#
# Протестируйте работу созданной нейронной сети на своих отзывах.

# %% [markdown]
# *Ниже даны подсказки по подготовке и выполнению задания*
#
# *Вам необходимо выполнить последовательность шагов, аналогичную той, что рассматривалась на занятии*

# %% [markdown]
# **1. Запустите ячейку ниже для установки модуля УИИ**

# %%
#@title Установка модуля УИИ
# !rm -rf sample_data

import seaborn as sns
import random
import os
import numpy as np
import tensorflow as tf
import gdown
from IPython.display import clear_output

# !pip -q install pymorphy2
# !pip -q install python-Levenshtein

# Установочные параметры
sns.set(style='darkgrid')
seed_value = 12
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
if not os.path.exists('/content/IntensiveTerra'):
  os.mkdir('/content/IntensiveTerra')
os.chdir('/content/IntensiveTerra')

# Загрузка модуля
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/intensivedaytwo.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/check_for_errors.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/dataset.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/text_process.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/квартиры.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/модель.py', None, quiet=True)

import intensivedaytwo

demo_ai = intensivedaytwo.TerraIntensive()
clear_output(wait=True)
# Out:
#      |████████████████████████████████| 55 kB 3.9 MB/s
#      |████████████████████████████████| 8.2 MB 61.8 MB/s
#      |████████████████████████████████| 50 kB 5.6 MB/s
# ...

# %% [markdown]
# **2. Загрузите датасет:**:

# %%
# Ваше решение

# %% [markdown]
# **3. Выведите примеры отзывов:**

# %%
# Ваше решение

# %% [markdown]
# **4. Сформируйте обучающую и проверочную выборки, указав необходимые параметры**:

# %%
# Задаем параметры для формирования выборок
vocab_size = ''
block_length = ''
block_step = ''

# Создание обучающей и проверочной выборок
demo_ai.create_sets(
    vocab_size,
    block_length,
    block_step,
)

# %% [markdown]
# **5. Укажите слои создаваемой нейронной сети:**

# %%
# Задание слоев нейронной сети
branch_1 = f'Эмбеддинг-2-{vocab_size}-{block_length}\
'

branch_2 = ''

branch_3 = ''

# Создание модели нейронной сети
demo_ai.create_model_combine(branch_1, branch_2, branch_3)

# %% [markdown]
# **6. Обучите созданную модель:**
#
# *Можете указать произвольное количество эпох*

# %%
# Ваше решение

# %% [markdown]
# **7. Протестируйте работу Вашей модели:**

# %%
# Ваше решение

# %% [markdown]
# <h1> <b> Задача №3 </b> </h1>
#
# <i>Закрепляющая</i>

# %% [markdown]
# **Описание задачи**
#
# У Вас появилась новая возможность: принять участие в разработке системы диагностики для мед.учреждений. Чтобы получить эту задачу, Вам необходимо разработать пилотный проект по предсказанию диагноза человека по симптомам.
#
# Заказчик предоставил текстовый датасет для 10 категорий заболеваний:
#
#     ['Колит', 'Гепатит', 'Гастрит', 'Холицестит', 'Дуоденит', 'Энтерит', 'Язва', 'Эзофагит', 'Аппендицит', 'Панкреатит']
#
# По аналогии с задачей по классификации отзывов автомобиля, создайте и обучите нейронную сеть для оформления пилотного проекта.
#
# Протестируйте работу созданной модели на произвольных симптомах (можно взять из интернета).

# %% [markdown]
# *Ниже даны подсказки по подготовке и выполнению задания*
#
# *Вам необходимо выполнить последовательность шагов, аналогичную той, что рассматривалась на занятии*

# %% [markdown]
# **1. Запустите ячейку ниже для установки модуля УИИ**

# %%
#@title Установка модуля УИИ
# !rm -rf sample_data

import seaborn as sns
import random
import os
import numpy as np
import tensorflow as tf
import gdown
from IPython.display import clear_output

# !pip -q install pymorphy2
# !pip -q install python-Levenshtein

# Установочные параметры
sns.set(style='darkgrid')
seed_value = 12
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
if not os.path.exists('/content/IntensiveTerra'):
  os.mkdir('/content/IntensiveTerra')
os.chdir('/content/IntensiveTerra')

# Загрузка модуля
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/intensivedaytwo.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/check_for_errors.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/dataset.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/text_process.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/квартиры.py', None, quiet=True)
gdown.download('https://storage.yandexcloud.net/aiueducation/Intensive/tools/модель.py', None, quiet=True)

import intensivedaytwo

demo_ai = intensivedaytwo.TerraIntensive()
clear_output(wait=True)
# Out:
#      |████████████████████████████████| 55 kB 3.9 MB/s
#      |████████████████████████████████| 8.2 MB 61.8 MB/s
#      |████████████████████████████████| 50 kB 5.6 MB/s
# ...

# %% [markdown]
# **2. Загрузите датасет, указав в качестве параметра `Симптомы`**:

# %%
# Ваше решение
demo_ai.load_dataset('')

# %% [markdown]
# **3. Выведите примеры симптомов:**

# %%
# Ваше решение

# %% [markdown]
# **4. Сформируйте обучающую и проверочную выборки, указав необходимые параметры**:
#
# *Выборка для данного датасета может подготавливаться более 10 мин*

# %%
# Задаем параметры для формирования выборок
vocab_size = ''
block_length = ''
block_step = ''

# Создание обучающей и проверочной выборок
demo_ai.create_sets(
    vocab_size,
    block_length,
    block_step,
)

# %% [markdown]
# **5. Укажите слои создаваемой нейронной сети:**

# %%
# Задание слоев нейронной сети
branch_1 = f'Эмбеддинг-2-{vocab_size}-{block_length}\
'

branch_2 = ''

branch_3 = ''

# Создание модели нейронной сети
demo_ai.create_model_combine(branch_1, branch_2, branch_3)

# %% [markdown]
# **6. Обучите созданную модель:**
#
# *Можете указать произвольное количество эпох*

# %%
# Ваше решение

# %% [markdown]
# **7. Протестируйте работу Вашей модели:**
#
# Пример симптомов:
#
#     'общая слабость;повышение температуры тела;систематические приступы тошноты;регулярную рвоту с примесями желчи.'

# %%
# Ваше решение
